# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/Moodle/blob/master/Encuesta_de_Incidentes_Criticos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import collections
import multiprocessing as mp
import re

# %%
def process(line):
  print(line)

# %%
with open('/content/Encuesta.txt') as f:
  data = f.readlines()
  for line in data:
    process(line)

# %%
with open('/content/Encuesta.txt') as f:
  for line in data:
    process(line)

# %%
data1 = (str(data))

# %%
print(data1)
# Out:
# ['ENCUESTA DE INCIDENTES CRITICOS\n', 'PREGUNTAS\n', 'Todas las preguntas son necesarias y deben ser contestadas\n', '¿En que momento, durante la clase, se sintio mas involucrado como estudiante? \n', '¿En que momento, durante la clase, se sintio mas distanciado como estudiante? \n', '¿Que accion, de cualquiera de sus participantes, le ha parecido mas util o positiva dentro del foro? \n', '¿Que accion dentro del foro le ha parecido mas compleja o confusa por parte de cualquiera de sus participantes? \n', '¿Que evento le ha sorprendido mas?\n', 'RESPUESTAS\n', 'Todas las preguntas en orden, todos los estudiantes\n', '¿En que momento, durante la clase, se sintio mas involucrado como estudiante?\n', 'Agustin Emanuel FARRERAS MARINO\n', 'Cuando el tema de trabajo fue crear mi empresa, ya que yo podia sentir un cierto tipo de atraccion por usar la tecnologia debido a que estaba creando algo que a mi realmente me interesaba y nacia de mi.\n', 'Ailen CONTRERAS\n', 'Ninguno\n', 'Soledad Tati
# ...

# %%
puntuacion = ".',¿?[]"

# %%
for p in puntuacion:
  data1 = data1.replace(p,'')

print(data1.split())
# Out:
# ['ENCUESTA', 'DE', 'INCIDENTES', 'CRITICOS\\n', 'PREGUNTAS\\n', 'Todas', 'las', 'preguntas', 'son', 'necesarias', 'y', 'deben', 'ser', 'contestadas\\n', 'En', 'que', 'momento', 'durante', 'la', 'clase', 'se', 'sintio', 'mas', 'involucrado', 'como', 'estudiante', '\\n', 'En', 'que', 'momento', 'durante', 'la', 'clase', 'se', 'sintio', 'mas', 'distanciado', 'como', 'estudiante', '\\n', 'Que', 'accion', 'de', 'cualquiera', 'de', 'sus', 'participantes', 'le', 'ha', 'parecido', 'mas', 'util', 'o', 'positiva', 'dentro', 'del', 'foro', '\\n', 'Que', 'accion', 'dentro', 'del', 'foro', 'le', 'ha', 'parecido', 'mas', 'compleja', 'o', 'confusa', 'por', 'parte', 'de', 'cualquiera', 'de', 'sus', 'participantes', '\\n', 'Que', 'evento', 'le', 'ha', 'sorprendido', 'mas\\n', 'RESPUESTAS\\n', 'Todas', 'las', 'preguntas', 'en', 'orden', 'todos', 'los', 'estudiantes\\n', 'En', 'que', 'momento', 'durante', 'la', 'clase', 'se', 'sintio', 'mas', 'involucrado', 'como', 'estudiante\\n', 'Agustin', 'Emanuel'
# ...

# %%
palabra = r'\\n+'
splitdata1 = re.split(palabra, data1)

print(splitdata1)
# Out:
# ['ENCUESTA DE INCIDENTES CRITICOS', ' PREGUNTAS', ' Todas las preguntas son necesarias y deben ser contestadas', ' En que momento durante la clase se sintio mas involucrado como estudiante ', ' En que momento durante la clase se sintio mas distanciado como estudiante ', ' Que accion de cualquiera de sus participantes le ha parecido mas util o positiva dentro del foro ', ' Que accion dentro del foro le ha parecido mas compleja o confusa por parte de cualquiera de sus participantes ', ' Que evento le ha sorprendido mas', ' RESPUESTAS', ' Todas las preguntas en orden todos los estudiantes', ' En que momento durante la clase se sintio mas involucrado como estudiante', ' Agustin Emanuel FARRERAS MARINO', ' Cuando el tema de trabajo fue crear mi empresa ya que yo podia sentir un cierto tipo de atraccion por usar la tecnologia debido a que estaba creando algo que a mi realmente me interesaba y nacia de mi', ' Ailen CONTRERAS', ' Ninguno', ' Soledad Tatiana CONDORI', ' Cuando se realizaban l
# ...

# %%
splitdata1 = (str(splitdata1))

# %%
puntuacion1 = "',"

# %%
for p in puntuacion1:
  splitdata1 = splitdata1.replace(p,'')

print(splitdata1.split())
# Out:
# ['[ENCUESTA', 'DE', 'INCIDENTES', 'CRITICOS', 'PREGUNTAS', 'Todas', 'las', 'preguntas', 'son', 'necesarias', 'y', 'deben', 'ser', 'contestadas', 'En', 'que', 'momento', 'durante', 'la', 'clase', 'se', 'sintio', 'mas', 'involucrado', 'como', 'estudiante', 'En', 'que', 'momento', 'durante', 'la', 'clase', 'se', 'sintio', 'mas', 'distanciado', 'como', 'estudiante', 'Que', 'accion', 'de', 'cualquiera', 'de', 'sus', 'participantes', 'le', 'ha', 'parecido', 'mas', 'util', 'o', 'positiva', 'dentro', 'del', 'foro', 'Que', 'accion', 'dentro', 'del', 'foro', 'le', 'ha', 'parecido', 'mas', 'compleja', 'o', 'confusa', 'por', 'parte', 'de', 'cualquiera', 'de', 'sus', 'participantes', 'Que', 'evento', 'le', 'ha', 'sorprendido', 'mas', 'RESPUESTAS', 'Todas', 'las', 'preguntas', 'en', 'orden', 'todos', 'los', 'estudiantes', 'En', 'que', 'momento', 'durante', 'la', 'clase', 'se', 'sintio', 'mas', 'involucrado', 'como', 'estudiante', 'Agustin', 'Emanuel', 'FARRERAS', 'MARINO', 'Cuando', 'el', 'tema', 
# ...
