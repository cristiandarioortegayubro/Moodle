# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/Moodle/blob/master/RecursosMoodle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plot
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
recurso = pd.read_excel('/content/recurso.xlsx')

# %%
recurso.head()
# Out:
#     RECURSOS  ...  CANTIDAD DE CURSOS PLA 1998
# 0    ARCHIVO  ...                           45
# 1   CARPETAS  ...                           35
# 2  ETIQUETAS  ...                           18
# 3      LIBRO  ...                            1
# 4     PaGINA  ...                            0
#
# [5 rows x 52 columns]

# %%
recurso.describe()
# Out:
#        ALGEBRA LINEAL  ...  CANTIDAD DE CURSOS PLA 1998
# count        7.000000  ...                     7.000000
# mean         0.285714  ...                    16.714286
# std          0.487950  ...                    17.698534
# min          0.000000  ...                     0.000000
# 25%          0.000000  ...                     1.500000
# 50%          0.000000  ...                    16.000000
# 75%          0.500000  ...                    26.500000
# max          1.000000  ...                    45.000000
#
# [8 rows x 51 columns]

# %%
plot.style.use('bmh')
recurso.plot('RECURSOS',['AUDITORiA OPERATIVA', 'ALGEBRA LINEAL'], kind='box', figsize=(11,6), color='darkblue')

# %%
plot.style.use('bmh')
recurso.plot('RECURSOS',['AUDITORiA OPERATIVA', 'ALGEBRA LINEAL'], kind='area', figsize=(11,6), color=['darkblue','green'])

# %%
import seaborn as sns
from fbprophet import Prophet
import pandas.util.testing as tm

# %%
participacionusuario = pd.read_excel('/content/ingresosestudiantes.xlsx')

# %%
participacionusuario.head()
# Out:
#        FECHA  INGRESOS
# 0 2017-01-01      7402
# 1 2017-01-02      6799
# 2 2017-01-03      6168
# 3 2017-01-04      5803
# 4 2017-01-05      5548

# %%
participacionusuario['INCREMENTO'] = participacionusuario.INGRESOS.pct_change()

# %%
participacionusuario.head()
# Out:
#        FECHA  INGRESOS  INCREMENTO
# 0 2017-01-01      7402         NaN
# 1 2017-01-02      6799   -0.081464
# 2 2017-01-03      6168   -0.092808
# 3 2017-01-04      5803   -0.059176
# 4 2017-01-05      5548   -0.043943

# %%
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.stats.diagnostic import acorr_ljungbox
import scipy.stats as scs

# %%
participacionusuario.plot('FECHA',['INCREMENTO'], kind='line', figsize=(11,6), color=['darkblue'])
